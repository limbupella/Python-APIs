# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key
# Define an empty list to fetch the weather data for each city
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    # Add 1 to the record count
    record_count += 1
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | ouani
# Processing Record 4 of Set 1 | nagqu
# Processing Record 5 of Set 1 | holualoa
# Processing Record 6 of Set 1 | glace bay
# Processing Record 7 of Set 1 | chernyshevskiy
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | sao gabriel da cachoeira
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | puttalam
# Processing Record 14 of Set 1 | saipan
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | port lincoln
# Processing Record 17 of Set 1 | anadyr
# Processing Record 18 of Set 1 | stanley
# Processing Record 19 of Set 1 | maubara
# City not found. Skipping...
# Processing Record 20 of Set 1 | kolokani
# Processing Record 21 of Set 1 | udachny
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | bilibino
# Processing Record 24 of Set 1 | orapa
# Processing Record 25 of Set 1 | afaahiti
# Processing Record 26 of Set 1 | pierre
# Processing Record 27 of Set 1 | oildale
# Processing Record 28 of Set 1 | timimoun
# Processing Record 29 of Set 1 | lorengau
# Processing Record 30 of Set 1 | al kharijah
# Processing Record 31 of Set 1 | sakakah
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | amga
# Processing Record 34 of Set 1 | grytviken
# Processing Record 35 of Set 1 | moires
# Processing Record 36 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 1 | tofol
# Processing Record 38 of Set 1 | blackmans bay
# Processing Record 39 of Set 1 | ancud
# Processing Record 40 of Set 1 | freeport
# Processing Record 41 of Set 1 | xianshuigu
# Processing Record 42 of Set 1 | whitehorse
# Processing Record 43 of Set 1 | tambopata
# Processing Record 44 of Set 1 | adamstown
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | mao
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | mweka
# Processing Record 49 of Set 1 | west island
# Processing Record 50 of Set 1 | vorkuta
# Processing Record 0 of Set 2 | borogontsy
# Processing Record 1 of Set 2 | emerald
# Processing Record 2 of Set 2 | reggane
# Processing Record 3 of Set 2 | eastham
# Processing Record 4 of Set 2 | suva
# Processing Record 5 of Set 2 | revda
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | edinburgh of the seven seas
# Processing Record 8 of Set 2 | caspe
# Processing Record 9 of Set 2 | atafu village
# Processing Record 10 of Set 2 | georgetown
# Processing Record 11 of Set 2 | benguela
# Processing Record 12 of Set 2 | banjarmasin
# Processing Record 13 of Set 2 | st. john's
# Processing Record 14 of Set 2 | aykhal
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 17 of Set 2 | dovzhansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | wailua homesteads
# Processing Record 19 of Set 2 | minas de marcona
# Processing Record 20 of Set 2 | castillos
# Processing Record 21 of Set 2 | zeya
# Processing Record 22 of Set 2 | bafq
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | kurim
# Processing Record 25 of Set 2 | port mathurin
# Processing Record 26 of Set 2 | lebu
# Processing Record 27 of Set 2 | dudinka
# Processing Record 28 of Set 2 | grand falls-windsor
# Processing Record 29 of Set 2 | aasiaat
# Processing Record 30 of Set 2 | dawei
# Processing Record 31 of Set 2 | enewetak
# Processing Record 32 of Set 2 | kakamega
# Processing Record 33 of Set 2 | yoichi
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | margaret river
# Processing Record 37 of Set 2 | nova sintra
# Processing Record 38 of Set 2 | masina
# Processing Record 39 of Set 2 | puerto natales
# Processing Record 40 of Set 2 | ocean city
# Processing Record 41 of Set 2 | papatowai
# Processing Record 42 of Set 2 | sosnovka
# Processing Record 43 of Set 2 | buchanan
# Processing Record 44 of Set 2 | greymouth
# Processing Record 45 of Set 2 | mukalla
# Processing Record 46 of Set 2 | bonanza
# Processing Record 47 of Set 2 | qaqortoq
# Processing Record 48 of Set 2 | talnakh
# Processing Record 49 of Set 2 | kulia village
# City not found. Skipping...
# Processing Record 0 of Set 3 | kirkwall
# Processing Record 1 of Set 3 | khandyga
# Processing Record 2 of Set 3 | kodiak
# Processing Record 3 of Set 3 | quartu sant'elena
# Processing Record 4 of Set 3 | kimberley
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | bel ombre
# Processing Record 7 of Set 3 | hawaiian paradise park
# Processing Record 8 of Set 3 | puerto deseado
# Processing Record 9 of Set 3 | belene
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | penzance
# Processing Record 12 of Set 3 | greenville
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 15 of Set 3 | la cruz
# Processing Record 16 of Set 3 | vadso
# Processing Record 17 of Set 3 | vysokiy
# Processing Record 18 of Set 3 | albany
# Processing Record 19 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 3 | igarka
# Processing Record 21 of Set 3 | tual
# Processing Record 22 of Set 3 | egilsstadir
# Processing Record 23 of Set 3 | turrialba
# Processing Record 24 of Set 3 | laascaanood
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | timmins
# Processing Record 27 of Set 3 | hadibu
# Processing Record 28 of Set 3 | qui nhon
# Processing Record 29 of Set 3 | ramotswa
# Processing Record 30 of Set 3 | flin flon
# Processing Record 31 of Set 3 | zhangatas
# Processing Record 32 of Set 3 | bardai
# Processing Record 33 of Set 3 | bamboo flat
# Processing Record 34 of Set 3 | keflavik
# Processing Record 35 of Set 3 | invercargill
# Processing Record 36 of Set 3 | kushiro
# Processing Record 37 of Set 3 | kerikeri
# Processing Record 38 of Set 3 | vila franca do campo
# Processing Record 39 of Set 3 | sinabang
# Processing Record 40 of Set 3 | palikir - national government center
# Processing Record 41 of Set 3 | nuuk
# Processing Record 42 of Set 3 | cannonvale
# Processing Record 43 of Set 3 | sidareja
# Processing Record 44 of Set 3 | susuman
# Processing Record 45 of Set 3 | vilyuysk
# Processing Record 46 of Set 3 | achkhoy-martan
# Processing Record 47 of Set 3 | constantia
# Processing Record 48 of Set 3 | punta arenas
# Processing Record 49 of Set 3 | hermanus
# Processing Record 0 of Set 4 | vigan
# Processing Record 1 of Set 4 | tranovaho
# City not found. Skipping...
# Processing Record 2 of Set 4 | gradistea
# Processing Record 3 of Set 4 | usinsk
# Processing Record 4 of Set 4 | broken hill
# Processing Record 5 of Set 4 | lihue
# Processing Record 6 of Set 4 | polyarnyy
# Processing Record 7 of Set 4 | vorgashor
# Processing Record 8 of Set 4 | mtimbira
# Processing Record 9 of Set 4 | turner
# Processing Record 10 of Set 4 | iskateley
# Processing Record 11 of Set 4 | shar
# Processing Record 12 of Set 4 | sao joao da barra
# Processing Record 13 of Set 4 | isafjordur
# Processing Record 14 of Set 4 | portland
# Processing Record 15 of Set 4 | coahuayana de hidalgo
# Processing Record 16 of Set 4 | lesogorsk
# Processing Record 17 of Set 4 | saraqib
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | hongwon
# Processing Record 20 of Set 4 | noumea
# Processing Record 21 of Set 4 | mil'kovo
# Processing Record 22 of Set 4 | alofi
# Processing Record 23 of Set 4 | as sulayyil
# Processing Record 24 of Set 4 | murzuq
# Processing Record 25 of Set 4 | klyuchi
# Processing Record 26 of Set 4 | tanout
# Processing Record 27 of Set 4 | hithadhoo
# Processing Record 28 of Set 4 | gadzhiyevo
# Processing Record 29 of Set 4 | taybad
# Processing Record 30 of Set 4 | olonkinbyen
# Processing Record 31 of Set 4 | ust-nera
# Processing Record 32 of Set 4 | mbanza-ngungu
# Processing Record 33 of Set 4 | bodaybo
# Processing Record 34 of Set 4 | puerto ayora
# Processing Record 35 of Set 4 | vytegra
# Processing Record 36 of Set 4 | la mira tumbiscatio
# Processing Record 37 of Set 4 | quang ngai
# Processing Record 38 of Set 4 | primorsk
# Processing Record 39 of Set 4 | tazovsky
# Processing Record 40 of Set 4 | sanctuary point
# Processing Record 41 of Set 4 | khanty-mansiysk
# Processing Record 42 of Set 4 | qom
# Processing Record 43 of Set 4 | saint-philippe
# Processing Record 44 of Set 4 | harstad
# Processing Record 45 of Set 4 | malakal
# Processing Record 46 of Set 4 | arteche
# Processing Record 47 of Set 4 | bouarfa
# Processing Record 48 of Set 4 | carutapera
# Processing Record 49 of Set 4 | andalgala
# Processing Record 0 of Set 5 | mutum
# Processing Record 1 of Set 5 | bourg-saint-maurice
# Processing Record 2 of Set 5 | mau aimma
# Processing Record 3 of Set 5 | elmendorf air force base
# City not found. Skipping...
# Processing Record 4 of Set 5 | neryungri
# Processing Record 5 of Set 5 | laguna de perlas
# Processing Record 6 of Set 5 | buon ma thuot
# Processing Record 7 of Set 5 | flying fish cove
# Processing Record 8 of Set 5 | barcelos
# Processing Record 9 of Set 5 | brookings
# Processing Record 10 of Set 5 | tiruchchendur
# Processing Record 11 of Set 5 | chonchi
# Processing Record 12 of Set 5 | warmbad
# Processing Record 13 of Set 5 | yeed
# Processing Record 14 of Set 5 | villa rica
# Processing Record 15 of Set 5 | aswan
# Processing Record 16 of Set 5 | chibougamau
# Processing Record 17 of Set 5 | saint-pierre
# Processing Record 18 of Set 5 | malilipot
# Processing Record 19 of Set 5 | punta cana
# Processing Record 20 of Set 5 | hamilton
# Processing Record 21 of Set 5 | jamestown
# Processing Record 22 of Set 5 | sisimiut
# Processing Record 23 of Set 5 | yerofey pavlovich
# Processing Record 24 of Set 5 | ingeniero jacobacci
# Processing Record 25 of Set 5 | north las vegas
# Processing Record 26 of Set 5 | kabalo
# Processing Record 27 of Set 5 | al mayadin
# Processing Record 28 of Set 5 | yonggang-up
# Processing Record 29 of Set 5 | viedma
# Processing Record 30 of Set 5 | luganville
# Processing Record 31 of Set 5 | labrador city
# Processing Record 32 of Set 5 | kone
# Processing Record 33 of Set 5 | weligama
# Processing Record 34 of Set 5 | khovd
# Processing Record 35 of Set 5 | porto novo
# Processing Record 36 of Set 5 | mwanza
# Processing Record 37 of Set 5 | tivat
# Processing Record 38 of Set 5 | nemuro
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | katsuura
# Processing Record 41 of Set 5 | prince george
# Processing Record 42 of Set 5 | redkino
# Processing Record 43 of Set 5 | urangan
# Processing Record 44 of Set 5 | klaksvik
# Processing Record 45 of Set 5 | zhanaozen
# Processing Record 46 of Set 5 | newman
# Processing Record 47 of Set 5 | hyesan
# Processing Record 48 of Set 5 | tinajo
# Processing Record 49 of Set 5 | maceio
# Processing Record 0 of Set 6 | sona
# Processing Record 1 of Set 6 | luza
# Processing Record 2 of Set 6 | port alfred
# Processing Record 3 of Set 6 | colonia menno
# Processing Record 4 of Set 6 | en naqoura
# City not found. Skipping...
# Processing Record 5 of Set 6 | embi
# Processing Record 6 of Set 6 | labytnangi
# Processing Record 7 of Set 6 | sao felix do xingu
# Processing Record 8 of Set 6 | sarmiento
# Processing Record 9 of Set 6 | kavaratti
# Processing Record 10 of Set 6 | kouroussa
# Processing Record 11 of Set 6 | mar del plata
# Processing Record 12 of Set 6 | alpena
# Processing Record 13 of Set 6 | luocheng
# Processing Record 14 of Set 6 | lompoc
# Processing Record 15 of Set 6 | amursk
# Processing Record 16 of Set 6 | nishinoomote
# Processing Record 17 of Set 6 | menongue
# Processing Record 18 of Set 6 | mrakovo
# Processing Record 19 of Set 6 | vallenar
# Processing Record 20 of Set 6 | mount pearl
# Processing Record 21 of Set 6 | mazouna
# Processing Record 22 of Set 6 | hohhot
# Processing Record 23 of Set 6 | lucapa
# Processing Record 24 of Set 6 | sumter
# Processing Record 25 of Set 6 | pisco
# Processing Record 26 of Set 6 | la union
# Processing Record 27 of Set 6 | champerico
# Processing Record 28 of Set 6 | okha
# Processing Record 29 of Set 6 | puerto baquerizo moreno
# Processing Record 30 of Set 6 | berezovyy
# Processing Record 31 of Set 6 | visconde do rio branco
# Processing Record 32 of Set 6 | ilulissat
# Processing Record 33 of Set 6 | vlore
# Processing Record 34 of Set 6 | eenhana
# Processing Record 35 of Set 6 | jining
# Processing Record 36 of Set 6 | tanjung selor
# City not found. Skipping...
# Processing Record 37 of Set 6 | savave village
# City not found. Skipping...
# Processing Record 38 of Set 6 | kapa'a
# Processing Record 39 of Set 6 | alice springs
# Processing Record 40 of Set 6 | nchelenge
# Processing Record 41 of Set 6 | nacala
# Processing Record 42 of Set 6 | huarmey
# Processing Record 43 of Set 6 | verkh-chebula
# Processing Record 44 of Set 6 | northam
# Processing Record 45 of Set 6 | al ghayzah
# Processing Record 46 of Set 6 | west bay
# Processing Record 47 of Set 6 | taulaga
# Processing Record 48 of Set 6 | broome
# Processing Record 49 of Set 6 | tvoroyri
# Processing Record 0 of Set 7 | okhotsk
# Processing Record 1 of Set 7 | juneau
# Processing Record 2 of Set 7 | vuktyl
# Processing Record 3 of Set 7 | lycksele
# Processing Record 4 of Set 7 | kolonia town
# Processing Record 5 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 6 of Set 7 | huayacocotla
# Processing Record 7 of Set 7 | kingston
# Processing Record 8 of Set 7 | buncrana
# Processing Record 9 of Set 7 | mount pleasant
# Processing Record 10 of Set 7 | trincomalee
# Processing Record 11 of Set 7 | asbe teferi
# Processing Record 12 of Set 7 | buhe
# Processing Record 13 of Set 7 | monrovia
# Processing Record 14 of Set 7 | ko pha ngan
# Processing Record 15 of Set 7 | sampaloc
# Processing Record 16 of Set 7 | forster
# Processing Record 17 of Set 7 | catumbela
# Processing Record 18 of Set 7 | jayapura
# Processing Record 19 of Set 7 | betio village
# Processing Record 20 of Set 7 | santo antonio
# Processing Record 21 of Set 7 | ta`u
# Processing Record 22 of Set 7 | bright
# Processing Record 23 of Set 7 | kargasok
# Processing Record 24 of Set 7 | hexham
# Processing Record 25 of Set 7 | westport
# Processing Record 26 of Set 7 | guaruja
# Processing Record 27 of Set 7 | guozhen
# Processing Record 28 of Set 7 | sarakhs
# Processing Record 29 of Set 7 | utrik
# Processing Record 30 of Set 7 | freetown
# Processing Record 31 of Set 7 | price
# Processing Record 32 of Set 7 | loreto
# Processing Record 33 of Set 7 | pointe-noire
# Processing Record 34 of Set 7 | san antonio de pale
# Processing Record 35 of Set 7 | envira
# Processing Record 36 of Set 7 | kapit
# Processing Record 37 of Set 7 | tevriz
# Processing Record 38 of Set 7 | thinadhoo
# Processing Record 39 of Set 7 | borba
# Processing Record 40 of Set 7 | badger
# Processing Record 41 of Set 7 | axim
# Processing Record 42 of Set 7 | malmesbury
# Processing Record 43 of Set 7 | vohipaho
# City not found. Skipping...
# Processing Record 44 of Set 7 | nadym
# Processing Record 45 of Set 7 | garoowe
# Processing Record 46 of Set 7 | thames
# Processing Record 47 of Set 7 | belyy yar
# Processing Record 48 of Set 7 | rio grande
# Processing Record 49 of Set 7 | brak
# Processing Record 0 of Set 8 | nar'yan-mar
# Processing Record 1 of Set 8 | beberibe
# Processing Record 2 of Set 8 | argo
# Processing Record 3 of Set 8 | kantharalak
# Processing Record 4 of Set 8 | caico
# Processing Record 5 of Set 8 | mumford
# Processing Record 6 of Set 8 | grootfontein
# Processing Record 7 of Set 8 | amahai
# Processing Record 8 of Set 8 | conception bay south
# Processing Record 9 of Set 8 | trosa
# Processing Record 10 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 11 of Set 8 | vernal
# Processing Record 12 of Set 8 | portage la prairie
# Processing Record 13 of Set 8 | new norfolk
# Processing Record 14 of Set 8 | kulachi
# Processing Record 15 of Set 8 | odienne
# Processing Record 16 of Set 8 | tura
# Processing Record 17 of Set 8 | crane
# Processing Record 18 of Set 8 | queenstown
# Processing Record 19 of Set 8 | mmabatho
# Processing Record 20 of Set 8 | berriane
# Processing Record 21 of Set 8 | port blair
# Processing Record 22 of Set 8 | yamada
# Processing Record 23 of Set 8 | tver
# Processing Record 24 of Set 8 | ismailia
# Processing Record 25 of Set 8 | ust'-ordynskiy
# Processing Record 26 of Set 8 | tado
# Processing Record 27 of Set 8 | male
# Processing Record 28 of Set 8 | yuxi
# Processing Record 29 of Set 8 | puerto aysen
# Processing Record 30 of Set 8 | verkhnevilyuysk
# Processing Record 31 of Set 8 | fortuna
# Processing Record 32 of Set 8 | bull savanna
# Processing Record 33 of Set 8 | quellon
# Processing Record 34 of Set 8 | howrah
# Processing Record 35 of Set 8 | pitimbu
# Processing Record 36 of Set 8 | avanigadda
# Processing Record 37 of Set 8 | nizhneangarsk
# Processing Record 38 of Set 8 | choyr
# Processing Record 39 of Set 8 | chokwe
# Processing Record 40 of Set 8 | cartersville
# Processing Record 41 of Set 8 | ocher
# Processing Record 42 of Set 8 | upington
# Processing Record 43 of Set 8 | kill devil hills
# Processing Record 44 of Set 8 | baia sprie
# Processing Record 45 of Set 8 | guangming
# Processing Record 46 of Set 8 | kabompo
# Processing Record 47 of Set 8 | howard springs
# Processing Record 48 of Set 8 | princeville
# Processing Record 49 of Set 8 | prince rupert
# Processing Record 0 of Set 9 | la passe
# Processing Record 1 of Set 9 | luena
# Processing Record 2 of Set 9 | punta de bombon
# Processing Record 3 of Set 9 | guntakal junction
# Processing Record 4 of Set 9 | hami
# Processing Record 5 of Set 9 | loango
# Processing Record 6 of Set 9 | yazman
# Processing Record 7 of Set 9 | santa cruz
# Processing Record 8 of Set 9 | ingeniero luis a. huergo
# Processing Record 9 of Set 9 | fortaleza
# Processing Record 10 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 11 of Set 9 | tazacorte
# Processing Record 12 of Set 9 | novyy urengoy
# Processing Record 13 of Set 9 | svetlyy
# Processing Record 14 of Set 9 | cabo san lucas
# Processing Record 15 of Set 9 | kuala terengganu
# Processing Record 16 of Set 9 | touros
# Processing Record 17 of Set 9 | kyshtovka
# Processing Record 18 of Set 9 | jianshui
# Processing Record 19 of Set 9 | bargara
# City not found. Skipping...
# Processing Record 20 of Set 9 | takoradi
# Processing Record 21 of Set 9 | tongouson
# Processing Record 22 of Set 9 | galle
# Processing Record 23 of Set 9 | skelleftea
# Processing Record 24 of Set 9 | haiku-pauwela
# Processing Record 25 of Set 9 | hassi messaoud
# Processing Record 26 of Set 9 | langepas
# Processing Record 27 of Set 9 | boende
# Processing Record 28 of Set 9 | battonya
# Processing Record 29 of Set 9 | hammerfest
# Processing Record 30 of Set 9 | sirjan
# Processing Record 31 of Set 9 | kourou
# Processing Record 32 of Set 9 | taltal
# Processing Record 33 of Set 9 | birjand
# Processing Record 34 of Set 9 | tulle
# Processing Record 35 of Set 9 | quelimane
# Processing Record 36 of Set 9 | coquimbo
# Processing Record 37 of Set 9 | fada
# Processing Record 38 of Set 9 | happy valley-goose bay
# Processing Record 39 of Set 9 | island harbour
# Processing Record 40 of Set 9 | santa rosalia
# Processing Record 41 of Set 9 | lerwick
# Processing Record 42 of Set 9 | kamyshevatskaya
# Processing Record 43 of Set 9 | estherville
# Processing Record 44 of Set 9 | dunedin
# Processing Record 45 of Set 9 | itaiba
# Processing Record 46 of Set 9 | concepcion
# Processing Record 47 of Set 9 | olyokminsk
# Processing Record 48 of Set 9 | fort st. john
# Processing Record 49 of Set 9 | arvayheer
# Processing Record 0 of Set 10 | weno
# Processing Record 1 of Set 10 | nakhon pathom
# Processing Record 2 of Set 10 | ikalamavony
# Processing Record 3 of Set 10 | novhorodka
# Processing Record 4 of Set 10 | gokceada
# Processing Record 5 of Set 10 | balkanabat
# Processing Record 6 of Set 10 | kota kinabalu
# Processing Record 7 of Set 10 | madang
# Processing Record 8 of Set 10 | tianpeng
# Processing Record 9 of Set 10 | adh dhibiyah
# City not found. Skipping...
# Processing Record 10 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 10 | parauapebas
# Processing Record 12 of Set 10 | guerrero negro
# Processing Record 13 of Set 10 | alappuzha
# Processing Record 14 of Set 10 | kalabo
# Processing Record 15 of Set 10 | illela
# Processing Record 16 of Set 10 | tromso
# Processing Record 17 of Set 10 | mahanoro
# Processing Record 18 of Set 10 | saarijarvi
# Processing Record 19 of Set 10 | bafata
# Processing Record 20 of Set 10 | sabha
# Processing Record 21 of Set 10 | rongelap
# Processing Record 22 of Set 10 | montepuez
# Processing Record 23 of Set 10 | colonia
# Processing Record 24 of Set 10 | badami
# Processing Record 25 of Set 10 | baruun-urt
# Processing Record 26 of Set 10 | sanchor
# Processing Record 27 of Set 10 | vershino-darasunskiy
# Processing Record 28 of Set 10 | chul'man
# Processing Record 29 of Set 10 | lamesa
# Processing Record 30 of Set 10 | horqueta
# Processing Record 31 of Set 10 | muhos
# Processing Record 32 of Set 10 | miyaly
# Processing Record 33 of Set 10 | ararat
# Processing Record 34 of Set 10 | shiyan
# Processing Record 35 of Set 10 | kayangel
# Processing Record 36 of Set 10 | cuatro cienegas de carranza
# Processing Record 37 of Set 10 | vernon
# Processing Record 38 of Set 10 | victoria falls
# Processing Record 39 of Set 10 | sola
# Processing Record 40 of Set 10 | uturoa
# Processing Record 41 of Set 10 | richards bay
# Processing Record 42 of Set 10 | novosibirsk
# Processing Record 43 of Set 10 | nantucket
# Processing Record 44 of Set 10 | saudarkrokur
# Processing Record 45 of Set 10 | itoman
# Processing Record 46 of Set 10 | muisne
# Processing Record 47 of Set 10 | saint-joseph
# Processing Record 48 of Set 10 | mu'minobod
# Processing Record 49 of Set 10 | makokou
# Processing Record 0 of Set 11 | saratamata
# City not found. Skipping...
# Processing Record 1 of Set 11 | safotulafai
# City not found. Skipping...
# Processing Record 2 of Set 11 | kodinsk
# Processing Record 3 of Set 11 | charlottetown
# Processing Record 4 of Set 11 | kailua-kona
# Processing Record 5 of Set 11 | taksimo
# Processing Record 6 of Set 11 | bikenibeu village
# Processing Record 7 of Set 11 | fuyu
# Processing Record 8 of Set 11 | east ballina
# Processing Record 9 of Set 11 | miastko
# Processing Record 10 of Set 11 | gerena
# Processing Record 11 of Set 11 | bandarbeyla
# Processing Record 12 of Set 11 | leh
# Processing Record 13 of Set 11 | loen
# Processing Record 14 of Set 11 | tamboril
# Processing Record 15 of Set 11 | huittinen
# Processing Record 16 of Set 11 | batticaloa
# Processing Record 17 of Set 11 | korla
# Processing Record 18 of Set 11 | zaoyang
# Processing Record 19 of Set 11 | puerto armuelles
# Processing Record 20 of Set 11 | minas de matahambre
# City not found. Skipping...
# Processing Record 21 of Set 11 | lander
# Processing Record 22 of Set 11 | salalah
# Processing Record 23 of Set 11 | luorong
# Processing Record 24 of Set 11 | inhumas
# Processing Record 25 of Set 11 | norilsk
# Processing Record 26 of Set 11 | poronaysk
# Processing Record 27 of Set 11 | capri
# Processing Record 28 of Set 11 | port moresby
# Processing Record 29 of Set 11 | gadani
# Processing Record 30 of Set 11 | norrtalje
# Processing Record 31 of Set 11 | nishon tumani
# Processing Record 32 of Set 11 | hengyang
# Processing Record 33 of Set 11 | scone
# Processing Record 34 of Set 11 | kavieng
# Processing Record 35 of Set 11 | taoudenni
# Processing Record 36 of Set 11 | zolochiv
# Processing Record 37 of Set 11 | sohag
# Processing Record 38 of Set 11 | tralee
# Processing Record 39 of Set 11 | bridgewater
# Processing Record 40 of Set 11 | mount gambier
# Processing Record 41 of Set 11 | kolondieba
# Processing Record 42 of Set 11 | kagizman
# Processing Record 43 of Set 11 | kemise
# Processing Record 44 of Set 11 | poptun
# Processing Record 45 of Set 11 | ha'il
# Processing Record 46 of Set 11 | guacimo
# Processing Record 47 of Set 11 | bijar
# Processing Record 48 of Set 11 | myitkyina
# Processing Record 49 of Set 11 | pavlohrad
# Processing Record 0 of Set 12 | altai
# Processing Record 1 of Set 12 | katabu
# Processing Record 2 of Set 12 | buritis
# Processing Record 3 of Set 12 | carlsbad
# Processing Record 4 of Set 12 | bikaner
# Processing Record 5 of Set 12 | kenai
# Processing Record 6 of Set 12 | el granada
# Processing Record 7 of Set 12 | hatillo
# Processing Record 8 of Set 12 | pervomayskoye
# Processing Record 9 of Set 12 | aras-asan
# Processing Record 10 of Set 12 | at-bashi
# Processing Record 11 of Set 12 | machico
# Processing Record 12 of Set 12 | remire-montjoly
# Processing Record 13 of Set 12 | chicxulub puerto
# City not found. Skipping...
# Processing Record 14 of Set 12 | at taj
# Processing Record 15 of Set 12 | moyale
# Processing Record 16 of Set 12 | kunashak
# Processing Record 17 of Set 12 | jebrail
# Processing Record 18 of Set 12 | inari
# Processing Record 19 of Set 12 | novobod
# Processing Record 20 of Set 12 | roma
# Processing Record 21 of Set 12 | srandakan
# Processing Record 22 of Set 12 | verin
# Processing Record 23 of Set 12 | illizi
# Processing Record 24 of Set 12 | saint-francois
# Processing Record 25 of Set 12 | aquin
# Processing Record 26 of Set 12 | olinda
# Processing Record 27 of Set 12 | rurrenabaque
# Processing Record 28 of Set 12 | los llanos de aridane
# Processing Record 29 of Set 12 | wattegama
# Processing Record 30 of Set 12 | tolanaro
# Processing Record 31 of Set 12 | oppdal
# Processing Record 32 of Set 12 | kerema
# Processing Record 33 of Set 12 | figuig (centre)
# Processing Record 34 of Set 12 | bol'shoye murashkino
# Processing Record 35 of Set 12 | ulladulla
# Processing Record 36 of Set 12 | den helder
# Processing Record 37 of Set 12 | hirosaki
# Processing Record 38 of Set 12 | tippi
# Processing Record 39 of Set 12 | val-d'or
# Processing Record 40 of Set 12 | lazaro cardenas
# Processing Record 41 of Set 12 | barah
# Processing Record 42 of Set 12 | yuzhno-kurilsk
# Processing Record 43 of Set 12 | laojunmiao
# Processing Record 44 of Set 12 | ceeldheer
# Processing Record 45 of Set 12 | porangatu
# Processing Record 46 of Set 12 | antsiranana
# Processing Record 47 of Set 12 | hovd
# Processing Record 48 of Set 12 | kuanda
# Processing Record 49 of Set 12 | andovoranto
# Processing Record 0 of Set 13 | oudtshoorn
# Processing Record 1 of Set 13 | mundybash
# Processing Record 2 of Set 13 | gbadolite
# Processing Record 3 of Set 13 | buguruslan
# Processing Record 4 of Set 13 | cristuru secuiesc
# Processing Record 5 of Set 13 | juan griego
# Processing Record 6 of Set 13 | darwin
# Processing Record 7 of Set 13 | gao
# Processing Record 8 of Set 13 | daru
# Processing Record 9 of Set 13 | chinde
# Processing Record 10 of Set 13 | lisakovsk
# Processing Record 11 of Set 13 | maragogi
# Processing Record 12 of Set 13 | morant bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          591
# Lat           591
# Lng           591
# Max Temp      591
# Humidity      591
# Cloudiness    591
# Wind Speed    591
# Country       591
# Date          591
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  waitangi -43.9535 -176.5597     12.68        87          60        0.45
# 1  thompson  55.7435  -97.8558     -9.91        92          75        0.00
# 2     ouani -12.1322   44.4258     27.75        78         100        2.21
# 3     nagqu  31.5000   92.0000     -8.48        75         100        1.57
# 4  holualoa  19.6228 -155.9522     22.65        86          40        1.54
#
#   Country        Date
# 0      NZ  1701973917
# 1      CA  1701973917
# 2      KM  1701973917
# 3      CN  1701973917
# 4      US  1701973677

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        waitangi -43.9535 -176.5597     12.68        87          60
# 1        thompson  55.7435  -97.8558     -9.91        92          75
# 2           ouani -12.1322   44.4258     27.75        78         100
# 3           nagqu  31.5000   92.0000     -8.48        75         100
# 4        holualoa  19.6228 -155.9522     22.65        86          40
#
#          Wind Speed Country        Date
# City_ID
# 0              0.45      NZ  1701973917
# 1              0.00      CA  1701973917
# 2              2.21      KM  1701973917
# 3              1.57      CN  1701973917
# 4              1.54      US  1701973677

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Lat")
plt.ylabel("Max Temp")
# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Lat")
plt.ylabel("Humidity")
# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Lat")
plt.ylabel("Cloudiness")
# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])
# Incorporate the other graph properties
# YOUR CODE HERE
plt.xlabel("Lat")
plt.ylabel("Wind Speed")
# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
